# %%
from astropy.io import fits
import matplotlib.pyplot as plt

plt.style.use('seaborn-whitegrid')

# %%
file = '/home/mimimustaine/Downloads/tractor-0001m002.fits'

# %%
hdul = fits.open(file)

# %%
hdul.info()
# Out:
# Filename: /home/mimimustaine/Downloads/tractor-0001m002.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU     161   ()
#   1                1 BinTableHDU    720   7142R x 160C   [I, J, 8A, J, L, I, I, 4A, D, D, E, E, E, E, 5E, E, D, D, 2A, K, E, E, E, E, E, E, E, L, E, E, I, E, E, I, E, E, I, L, E, E, I, I, E, L, E, E, E, E, B, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, 8E, 8E, 8E, 8E, 8E, 8E, 8E, 8E, 8E, E, E, E, E, E, E, E, I, I, I, I, I, I, I, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, I, I, I, I, I, I, B, B, E, E, E, E, E, E, E, E, E, E, E, E, E, 8A, 11E, 11E, 11E, 11E, 11I, 11I, 11E, 11E, 11E, 11E, 11D, 11D, E, E, E, E, E, E, E, E, E, E, E, E, E, E]

# %%
data1 = hdul[1].data
data1_hdr =hdul[1].header
data1_hdr
# Out:
# XTENSION= 'BINTABLE'           / binary table extension
# BITPIX  =                    8 / 8-bit bytes
# NAXIS   =                    2 / 2-dimensional binary table
# NAXIS1  =                 1395 / width of table in bytes
# NAXIS2  =                 7142 / number of rows in table
# PCOUNT  =                    0 / size of special data area
# GCOUNT  =                    1 / one data group (required keyword)
# TFIELDS =                  160 / number of fields in each row
# TTYPE1  = 'release '           / label for field   1
# TFORM1  = 'I       '           / data format of field: 2-byte INTEGER
# TTYPE2  = 'brickid '           / label for field   2
# TFORM2  = 'J       '           / data format of field: 4-byte INTEGER
# TTYPE3  = 'brickname'          / label for field   3
# TFORM3  = '8A      '           / data format of field: ASCII Character
# TTYPE4  = 'objid   '           / label for field   4
# TFORM4  = 'J       '           / data format of field: 4-byte INTEGER
# TTYPE5  = 'brick_primary'      / label for field   5
# TFORM5  = 'L       '           / data format of field: 1-byte LOGICAL
# TTYPE6  = 'brightblob'         / label for field   6
# TFORM6  = 'I       '           / data format of field: 2-byte INTEGER
# TTYPE7  = 'maskbits'           / label for field   7
# TFORM7  = 'I       '           / data format of field: 2-byte INTEGER
# TTYPE8  = 'type    '           / label for field   8
# TFORM8  = '4A      '           / data format of field: ASCII Character
# TTYPE9  = 'ra      '           / label for field   9
# TFORM9  = 'D       '           / data format of field: 8-byte DOUBLE
# TTYPE10 = 'dec     '           / label for field  10
# TFORM10 = 'D       '           / data format of field: 8-byte DOUBLE
# TTYPE11 = 'ra_ivar '           / label for field  11
# TFORM11 = 'E       '           / data format of field: 4-byte REAL
# TTYPE12 = 'dec_ivar'           / label for field  12
# TFORM12 = 'E       '           / data format of field: 4-byte REAL
# TTYPE13 = 'bx      '           / label for field  13
# TFORM13 = 'E       '           / data format of field: 4-byte REAL
# TUNIT13 = 'pix     '           / physical unit of field
# TTYPE14 = 'by      '           / label for field  14
# TFORM14 = 'E       '           / data format of field: 4-byte REAL
# TUNIT14 = 'pix     '           / physical unit of field
# TTYPE15 = 'dchisq  '           / label for field  15
# TFORM15 = '5E      '           / data format of field: 4-byte REAL
# TTYPE16 = 'ebv     '           / label for field  16
# TFORM16 = 'E       '           / data format of field: 4-byte REAL
# TTYPE17 = 'mjd_min '           / label for field  17
# TFORM17 = 'D       '           / data format of field: 8-byte DOUBLE
# TTYPE18 = 'mjd_max '           / label for field  18
# TFORM18 = 'D       '           / data format of field: 8-byte DOUBLE
# TTYPE19 = 'ref_cat '           / label for field  19
# TFORM19 = '2A      '           / data format of field: ASCII Character
# TTYPE20 = 'ref_id  '           / label for field  20
# TFORM20 = 'K       '           / data format of field: 8-byte INTEGER
# TTYPE21 = 'pmra    '           / label for field  21
# TFORM21 = 'E       '           / data format of field: 4-byte REAL
# TUNIT21 = 'mas/yr  '           / physical unit of field
# TTYPE22 = 'pmdec   '           / label for field  22
# TFORM22 = 'E       '           / data format of field: 4-byte REAL
# TUNIT22 = 'mas/yr  '           / physical unit of field
# TTYPE23 = 'parallax'           / label for field  23
# TFORM23 = 'E       '           / data format of field: 4-byte REAL
# TUNIT23 = 'mas     '           / physical unit of field
# TTYPE24 = 'pmra_ivar'          / label for field  24
# TFORM24 = 'E       '           / data format of field: 4-byte REAL
# TUNIT24 = '1/(mas/yr)^2'       / physical unit of field
# TTYPE25 = 'pmdec_ivar'         / label for field  25
# TFORM25 = 'E       '           / data format of field: 4-byte REAL
# TUNIT25 = '1/(mas/yr)^2'       / physical unit of field
# TTYPE26 = 'parallax_ivar'      / label for field  26
# TFORM26 = 'E       '           / data format of field: 4-byte REAL
# TUNIT26 = '1/mas^2 '           / physical unit of field
# TTYPE27 = 'ref_epoch'          / label for field  27
# TFORM27 = 'E       '           / data format of field: 4-byte REAL
# TUNIT27 = 'yr      '           / physical unit of field
# TTYPE28 = 'gaia_pointsource'   / label for field  28
# TFORM28 = 'L       '           / data format of field: 1-byte LOGICAL
# TTYPE29 = 'gaia_phot_g_mean_mag' / label for field  29
# TFORM29 = 'E       '           / data format of field: 4-byte REAL
# TUNIT29 = 'mag     '           / physical unit of field
# TTYPE30 = 'gaia_phot_g_mean_flux_over_error' / label for field  30
# TFORM30 = 'E       '           / data format of field: 4-byte REAL
# TTYPE31 = 'gaia_phot_g_n_obs'  / label for field  31
# TFORM31 = 'I       '           / data format of field: 2-byte INTEGER
# TTYPE32 = 'gaia_phot_bp_mean_mag' / label for field  32
# TFORM32 = 'E       '           / data format of field: 4-byte REAL
# TUNIT32 = 'mag     '           / physical unit of field
# TTYPE33 = 'gaia_phot_bp_mean_flux_over_error' / label for field  33
# TFORM33 = 'E       '           / data format of field: 4-byte REAL
# TTYPE34 = 'gaia_phot_bp_n_obs' / label for field  34
# TFORM34 = 'I       '           / data format of field: 2-byte INTEGER
# TTYPE35 = 'gaia_phot_rp_mean_mag' / label for field  35
# TFORM35 = 'E       '           / data format of field: 4-byte REAL
# TUNIT35 = 'mag     '           / physical unit of field
# TTYPE36 = 'gaia_phot_rp_mean_flux_over_error' / label for field  36
# TFORM36 = 'E       '           / data format of field: 4-byte REAL
# TTYPE37 = 'gaia_phot_rp_n_obs' / label for field  37
# TFORM37 = 'I       '           / data format of field: 2-byte INTEGER
# TTYPE38 = 'gaia_phot_variable_flag' / label for field  38
# TFORM38 = 'L       '           / data format of field: 1-byte LOGICAL
# TTYPE39 = 'gaia_astrometric_excess_noise' / label for field  39
# TFORM39 = 'E       '           / data format of field: 4-byte REAL
# TTYPE40 = 'gaia_astrometric_excess_noise_sig' / label for field  40
# TFORM40 = 'E       '           / data format of field: 4-byte REAL
# TTYPE41 = 'gaia_astrometric_n_obs_al' / label for field  41
# TFORM41 = 'I       '           / data format of field: 2-byte INTEGER
# TTYPE42 = 'gaia_astrometric_n_good_obs_al' / label for field  42
# TFORM42 = 'I       '           / data format of field: 2-byte INTEGER
# TTYPE43 = 'gaia_astrometric_weight_al' / label for field  43
# TFORM43 = 'E       '           / data format of field: 4-byte REAL
# TTYPE44 = 'gaia_duplicated_source' / label for field  44
# TFORM44 = 'L       '           / data format of field: 1-byte LOGICAL
# TTYPE45 = 'gaia_a_g_val'       / label for field  45
# TFORM45 = 'E       '           / data format of field: 4-byte REAL
# TTYPE46 = 'gaia_e_bp_min_rp_val' / label for field  46
# TFORM46 = 'E       '           / data format of field: 4-byte REAL
# TTYPE47 = 'gaia_phot_bp_rp_excess_factor' / label for field  47
# TFORM47 = 'E       '           / data format of field: 4-byte REAL
# TTYPE48 = 'gaia_astrometric_sigma5d_max' / label for field  48
# TFORM48 = 'E       '           / data format of field: 4-byte REAL
# TTYPE49 = 'gaia_astrometric_params_solved' / label for field  49
# TFORM49 = 'B       '           / data format of field: BYTE
# TTYPE50 = 'flux_g  '           / label for field  50
# TFORM50 = 'E       '           / data format of field: 4-byte REAL
# TTYPE51 = 'flux_r  '           / label for field  51
# TFORM51 = 'E       '           / data format of field: 4-byte REAL
# TTYPE52 = 'flux_z  '           / label for field  52
# TFORM52 = 'E       '           / data format of field: 4-byte REAL
# TTYPE53 = 'flux_w1 '           / label for field  53
# TFORM53 = 'E       '           / data format of field: 4-byte REAL
# TTYPE54 = 'flux_w2 '           / label for field  54
# TFORM54 = 'E       '           / data format of field: 4-byte REAL
# TTYPE55 = 'flux_w3 '           / label for field  55
# TFORM55 = 'E       '           / data format of field: 4-byte REAL
# TTYPE56 = 'flux_w4 '           / label for field  56
# TFORM56 = 'E       '           / data format of field: 4-byte REAL
# TTYPE57 = 'flux_ivar_g'        / label for field  57
# TFORM57 = 'E       '           / data format of field: 4-byte REAL
# TTYPE58 = 'flux_ivar_r'        / label for field  58
# TFORM58 = 'E       '           / data format of field: 4-byte REAL
# TTYPE59 = 'flux_ivar_z'        / label for field  59
# TFORM59 = 'E       '           / data format of field: 4-byte REAL
# TTYPE60 = 'flux_ivar_w1'       / label for field  60
# TFORM60 = 'E       '           / data format of field: 4-byte REAL
# TTYPE61 = 'flux_ivar_w2'       / label for field  61
# TFORM61 = 'E       '           / data format of field: 4-byte REAL
# TTYPE62 = 'flux_ivar_w3'       / label for field  62
# TFORM62 = 'E       '           / data format of field: 4-byte REAL
# TTYPE63 = 'flux_ivar_w4'       / label for field  63
# TFORM63 = 'E       '           / data format of field: 4-byte REAL
# TTYPE64 = 'fiberflux_g'        / label for field  64
# TFORM64 = 'E       '           / data format of field: 4-byte REAL
# TTYPE65 = 'fiberflux_r'        / label for field  65
# TFORM65 = 'E       '           / data format of field: 4-byte REAL
# TTYPE66 = 'fiberflux_z'        / label for field  66
# TFORM66 = 'E       '           / data format of field: 4-byte REAL
# TTYPE67 = 'fibertotflux_g'     / label for field  67
# TFORM67 = 'E       '           / data format of field: 4-byte REAL
# TTYPE68 = 'fibertotflux_r'     / label for field  68
# TFORM68 = 'E       '           / data format of field: 4-byte REAL
# TTYPE69 = 'fibertotflux_z'     / label for field  69
# TFORM69 = 'E       '           / data format of field: 4-byte REAL
# TTYPE70 = 'apflux_g'           / label for field  70
# TFORM70 = '8E      '           / data format of field: 4-byte REAL
# TTYPE71 = 'apflux_r'           / label for field  71
# TFORM71 = '8E      '           / data format of field: 4-byte REAL
# TTYPE72 = 'apflux_z'           / label for field  72
# TFORM72 = '8E      '           / data format of field: 4-byte REAL
# TTYPE73 = 'apflux_resid_g'     / label for field  73
# TFORM73 = '8E      '           / data format of field: 4-byte REAL
# TTYPE74 = 'apflux_resid_r'     / label for field  74
# TFORM74 = '8E      '           / data format of field: 4-byte REAL
# TTYPE75 = 'apflux_resid_z'     / label for field  75
# TFORM75 = '8E      '           / data format of field: 4-byte REAL
# TTYPE76 = 'apflux_ivar_g'      / label for field  76
# TFORM76 = '8E      '           / data format of field: 4-byte REAL
# TTYPE77 = 'apflux_ivar_r'      / label for field  77
# TFORM77 = '8E      '           / data format of field: 4-byte REAL
# TTYPE78 = 'apflux_ivar_z'      / label for field  78
# TFORM78 = '8E      '           / data format of field: 4-byte REAL
# TTYPE79 = 'mw_transmission_g'  / label for field  79
# TFORM79 = 'E       '           / data format of field: 4-byte REAL
# TTYPE80 = 'mw_transmission_r'  / label for field  80
# TFORM80 = 'E       '           / data format of field: 4-byte REAL
# TTYPE81 = 'mw_transmission_z'  / label for field  81
# TFORM81 = 'E       '           / data format of field: 4-byte REAL
# TTYPE82 = 'mw_transmission_w1' / label for field  82
# TFORM82 = 'E       '           / data format of field: 4-byte REAL
# TTYPE83 = 'mw_transmission_w2' / label for field  83
# TFORM83 = 'E       '           / data format of field: 4-byte REAL
# TTYPE84 = 'mw_transmission_w3' / label for field  84
# TFORM84 = 'E       '           / data format of field: 4-byte REAL
# TTYPE85 = 'mw_transmission_w4' / label for field  85
# TFORM85 = 'E       '           / data format of field: 4-byte REAL
# TTYPE86 = 'nobs_g  '           / label for field  86
# TFORM86 = 'I       '           / data format of field: 2-byte INTEGER
# TTYPE87 = 'nobs_r  '           / label for field  87
# TFORM87 = 'I       '           / data format of field: 2-byte INTEGER
# TTYPE88 = 'nobs_z  '           / label for field  88
# TFORM88 = 'I       '           / data format of field: 2-byte INTEGER
# TTYPE89 = 'nobs_w1 '           / label for field  89
# TFORM89 = 'I       '           / data format of field: 2-byte INTEGER
# TTYPE90 = 'nobs_w2 '           / label for field  90
# TFORM90 = 'I       '           / data format of field: 2-byte INTEGER
# TTYPE91 = 'nobs_w3 '           / label for field  91
# TFORM91 = 'I       '           / data format of field: 2-byte INTEGER
# TTYPE92 = 'nobs_w4 '           / label for field  92
# TFORM92 = 'I       '           / data format of field: 2-byte INTEGER
# TTYPE93 = 'rchisq_g'           / label for field  93
# TFORM93 = 'E       '           / data format of field: 4-byte REAL
# TTYPE94 = 'rchisq_r'           / label for field  94
# TFORM94 = 'E       '           / data format of field: 4-byte REAL
# TTYPE95 = 'rchisq_z'           / label for field  95
# TFORM95 = 'E       '           / data format of field: 4-byte REAL
# TTYPE96 = 'rchisq_w1'          / label for field  96
# TFORM96 = 'E       '           / data format of field: 4-byte REAL
# TTYPE97 = 'rchisq_w2'          / label for field  97
# TFORM97 = 'E       '           / data format of field: 4-byte REAL
# TTYPE98 = 'rchisq_w3'          / label for field  98
# TFORM98 = 'E       '           / data format of field: 4-byte REAL
# TTYPE99 = 'rchisq_w4'          / label for field  99
# TFORM99 = 'E       '           / data format of field: 4-byte REAL
# TTYPE100= 'fracflux_g'         / label for field 100
# TFORM100= 'E       '           / data format of field: 4-byte REAL
# TTYPE101= 'fracflux_r'         / label for field 101
# TFORM101= 'E       '           / data format of field: 4-byte REAL
# TTYPE102= 'fracflux_z'         / label for field 102
# TFORM102= 'E       '           / data format of field: 4-byte REAL
# TTYPE103= 'fracflux_w1'        / label for field 103
# TFORM103= 'E       '           / data format of field: 4-byte REAL
# TTYPE104= 'fracflux_w2'        / label for field 104
# TFORM104= 'E       '           / data format of field: 4-byte REAL
# TTYPE105= 'fracflux_w3'        / label for field 105
# TFORM105= 'E       '           / data format of field: 4-byte REAL
# TTYPE106= 'fracflux_w4'        / label for field 106
# TFORM106= 'E       '           / data format of field: 4-byte REAL
# TTYPE107= 'fracmasked_g'       / label for field 107
# TFORM107= 'E       '           / data format of field: 4-byte REAL
# TTYPE108= 'fracmasked_r'       / label for field 108
# TFORM108= 'E       '           / data format of field: 4-byte REAL
# TTYPE109= 'fracmasked_z'       / label for field 109
# TFORM109= 'E       '           / data format of field: 4-byte REAL
# TTYPE110= 'fracin_g'           / label for field 110
# TFORM110= 'E       '           / data format of field: 4-byte REAL
# TTYPE111= 'fracin_r'           / label for field 111
# TFORM111= 'E       '           / data format of field: 4-byte REAL
# TTYPE112= 'fracin_z'           / label for field 112
# TFORM112= 'E       '           / data format of field: 4-byte REAL
# TTYPE113= 'anymask_g'          / label for field 113
# TFORM113= 'I       '           / data format of field: 2-byte INTEGER
# TTYPE114= 'anymask_r'          / label for field 114
# TFORM114= 'I       '           / data format of field: 2-byte INTEGER
# TTYPE115= 'anymask_z'          / label for field 115
# TFORM115= 'I       '           / data format of field: 2-byte INTEGER
# TTYPE116= 'allmask_g'          / label for field 116
# TFORM116= 'I       '           / data format of field: 2-byte INTEGER
# TTYPE117= 'allmask_r'          / label for field 117
# TFORM117= 'I       '           / data format of field: 2-byte INTEGER
# TTYPE118= 'allmask_z'          / label for field 118
# TFORM118= 'I       '           / data format of field: 2-byte INTEGER
# TTYPE119= 'wisemask_w1'        / label for field 119
# TFORM119= 'B       '           / data format of field: BYTE
# TTYPE120= 'wisemask_w2'        / label for field 120
# TFORM120= 'B       '           / data format of field: BYTE
# TTYPE121= 'psfsize_g'          / label for field 121
# TFORM121= 'E       '           / data format of field: 4-byte REAL
# TTYPE122= 'psfsize_r'          / label for field 122
# TFORM122= 'E       '           / data format of field: 4-byte REAL
# TTYPE123= 'psfsize_z'          / label for field 123
# TFORM123= 'E       '           / data format of field: 4-byte REAL
# TTYPE124= 'psfdepth_g'         / label for field 124
# TFORM124= 'E       '           / data format of field: 4-byte REAL
# TTYPE125= 'psfdepth_r'         / label for field 125
# TFORM125= 'E       '           / data format of field: 4-byte REAL
# TTYPE126= 'psfdepth_z'         / label for field 126
# TFORM126= 'E       '           / data format of field: 4-byte REAL
# TTYPE127= 'galdepth_g'         / label for field 127
# TFORM127= 'E       '           / data format of field: 4-byte REAL
# TTYPE128= 'galdepth_r'         / label for field 128
# TFORM128= 'E       '           / data format of field: 4-byte REAL
# TTYPE129= 'galdepth_z'         / label for field 129
# TFORM129= 'E       '           / data format of field: 4-byte REAL
# TTYPE130= 'psfdepth_w1'        / label for field 130
# TFORM130= 'E       '           / data format of field: 4-byte REAL
# TUNIT130= '1/nanomaggy^2'      / physical unit of field
# TTYPE131= 'psfdepth_w2'        / label for field 131
# TFORM131= 'E       '           / data format of field: 4-byte REAL
# TUNIT131= '1/nanomaggy^2'      / physical unit of field
# TTYPE132= 'psfdepth_w3'        / label for field 132
# TFORM132= 'E       '           / data format of field: 4-byte REAL
# TUNIT132= '1/nanomaggy^2'      / physical unit of field
# TTYPE133= 'psfdepth_w4'        / label for field 133
# TFORM133= 'E       '           / data format of field: 4-byte REAL
# TUNIT133= '1/nanomaggy^2'      / physical unit of field
# TTYPE134= 'wise_coadd_id'      / label for field 134
# TFORM134= '8A      '           / data format of field: ASCII Character
# TTYPE135= 'lc_flux_w1'         / label for field 135
# TFORM135= '11E     '           / data format of field: 4-byte REAL
# TTYPE136= 'lc_flux_w2'         / label for field 136
# TFORM136= '11E     '           / data format of field: 4-byte REAL
# TTYPE137= 'lc_flux_ivar_w1'    / label for field 137
# TFORM137= '11E     '           / data format of field: 4-byte REAL
# TTYPE138= 'lc_flux_ivar_w2'    / label for field 138
# TFORM138= '11E     '           / data format of field: 4-byte REAL
# TTYPE139= 'lc_nobs_w1'         / label for field 139
# TFORM139= '11I     '           / data format of field: 2-byte INTEGER
# TTYPE140= 'lc_nobs_w2'         / label for field 140
# TFORM140= '11I     '           / data format of field: 2-byte INTEGER
# TTYPE141= 'lc_fracflux_w1'     / label for field 141
# TFORM141= '11E     '           / data format of field: 4-byte REAL
# TTYPE142= 'lc_fracflux_w2'     / label for field 142
# TFORM142= '11E     '           / data format of field: 4-byte REAL
# TTYPE143= 'lc_rchisq_w1'       / label for field 143
# TFORM143= '11E     '           / data format of field: 4-byte REAL
# TTYPE144= 'lc_rchisq_w2'       / label for field 144
# TFORM144= '11E     '           / data format of field: 4-byte REAL
# TTYPE145= 'lc_mjd_w1'          / label for field 145
# TFORM145= '11D     '           / data format of field: 8-byte DOUBLE
# TTYPE146= 'lc_mjd_w2'          / label for field 146
# TFORM146= '11D     '           / data format of field: 8-byte DOUBLE
# TTYPE147= 'fracdev '           / label for field 147
# TFORM147= 'E       '           / data format of field: 4-byte REAL
# TTYPE148= 'fracdev_ivar'       / label for field 148
# TFORM148= 'E       '           / data format of field: 4-byte REAL
# TTYPE149= 'shapeexp_r'         / label for field 149
# TFORM149= 'E       '           / data format of field: 4-byte REAL
# TTYPE150= 'shapeexp_r_ivar'    / label for field 150
# TFORM150= 'E       '           / data format of field: 4-byte REAL
# TTYPE151= 'shapeexp_e1'        / label for field 151
# TFORM151= 'E       '           / data format of field: 4-byte REAL
# TTYPE152= 'shapeexp_e1_ivar'   / label for field 152
# TFORM152= 'E       '           / data format of field: 4-byte REAL
# TTYPE153= 'shapeexp_e2'        / label for field 153
# TFORM153= 'E       '           / data format of field: 4-byte REAL
# TTYPE154= 'shapeexp_e2_ivar'   / label for field 154
# TFORM154= 'E       '           / data format of field: 4-byte REAL
# TTYPE155= 'shapedev_r'         / label for field 155
# TFORM155= 'E       '           / data format of field: 4-byte REAL
# TTYPE156= 'shapedev_r_ivar'    / label for field 156
# TFORM156= 'E       '           / data format of field: 4-byte REAL
# TTYPE157= 'shapedev_e1'        / label for field 157
# TFORM157= 'E       '           / data format of field: 4-byte REAL
# TTYPE158= 'shapedev_e1_ivar'   / label for field 158
# TFORM158= 'E       '           / data format of field: 4-byte REAL
# TTYPE159= 'shapedev_e2'        / label for field 159
# TFORM159= 'E       '           / data format of field: 4-byte REAL
# TTYPE160= 'shapedev_e2_ivar'   / label for field 160
# TFORM160= 'E       '           / data format of field: 4-byte REAL
# TR_VER  =                    1 / Tractor output format version
# TR_D_P0 = 'pos.ra  '           / Tractor param name
# TR_D_P1 = 'pos.dec '           / Tractor param name
# TR_D_P2 = 'brightness.g'       / Tractor param name
# TR_D_P3 = 'brightness.r'       / Tractor param name
# TR_D_P4 = 'brightness.z'       / Tractor param name
# TR_D_P5 = 'shape.re'           / Tractor param name
# TR_D_P6 = 'shape.e1'           / Tractor param name
# TR_D_P7 = 'shape.e2'           / Tractor param name
# TR_D_T0 = 'tractor.galaxy.DevGalaxy' / Tractor param type
# TR_D_T1 = 'tractor.wcs.RaDecPos' / Tractor param type
# TR_D_T2 = 'tractor.brightness.NanoMaggies' / Tractor param type
# TR_D_T3 = 'tractor.ellipses.EllipseE' / Tractor param type
# TR_E_P0 = 'pos.ra  '           / Tractor param name
# TR_E_P1 = 'pos.dec '           / Tractor param name
# TR_E_P2 = 'brightness.g'       / Tractor param name
# TR_E_P3 = 'brightness.r'       / Tractor param name
# TR_E_P4 = 'brightness.z'       / Tractor param name
# TR_E_P5 = 'shape.re'           / Tractor param name
# TR_E_P6 = 'shape.e1'           / Tractor param name
# TR_E_P7 = 'shape.e2'           / Tractor param name
# TR_E_T0 = 'tractor.galaxy.ExpGalaxy' / Tractor param type
# TR_E_T1 = 'tractor.wcs.RaDecPos' / Tractor param type
# TR_E_T2 = 'tractor.brightness.NanoMaggies' / Tractor param type
# TR_E_T3 = 'tractor.ellipses.EllipseE' / Tractor param type
# TR_C_P0 = 'pos.ra  '           / Tractor param name
# TR_C_P1 = 'pos.dec '           / Tractor param name
# TR_C_P2 = 'brightness.g'       / Tractor param name
# TR_C_P3 = 'brightness.r'       / Tractor param name
# TR_C_P4 = 'brightness.z'       / Tractor param name
# TR_C_P5 = 'fracDev.FracDev'    / Tractor param name
# TR_C_P6 = 'shapeExp.re'        / Tractor param name
# TR_C_P7 = 'shapeExp.e1'        / Tractor param name
# TR_C_P8 = 'shapeExp.e2'        / Tractor param name
# TR_C_P9 = 'shapeDev.re'        / Tractor param name
# TR_C_P10= 'shapeDev.e1'        / Tractor param name
# TR_C_P11= 'shapeDev.e2'        / Tractor param name
# TR_C_T0 = 'tractor.galaxy.FixedCompositeGalaxy' / Tractor param type
# TR_C_T1 = 'tractor.wcs.RaDecPos' / Tractor param type
# TR_C_T2 = 'tractor.brightness.NanoMaggies' / Tractor param type
# TR_C_T3 = 'tractor.galaxy.FracDev' / Tractor param type
# TR_C_T4 = 'tractor.ellipses.EllipseE' / Tractor param type
# TR_C_T5 = 'tractor.ellipses.EllipseE' / Tractor param type
# TR_R_P0 = 'pos.ra  '           / Tractor param name
# TR_R_P1 = 'pos.dec '           / Tractor param name
# TR_R_P2 = 'brightness.g'       / Tractor param name
# TR_R_P3 = 'brightness.r'       / Tractor param name
# TR_R_P4 = 'brightness.z'       / Tractor param name
# TR_R_P5 = 'shape.re'           / Tractor param name
# TR_R_P6 = 'shape.e1'           / Tractor param name
# TR_R_P7 = 'shape.e2'           / Tractor param name
# TR_R_T0 = 'legacypipe.survey.RexGalaxy' / Tractor param type
# TR_R_T1 = 'tractor.wcs.RaDecPos' / Tractor param type
# TR_R_T2 = 'tractor.brightness.NanoMaggies' / Tractor param type
# TR_R_T3 = 'tractor.ellipses.EllipseE' / Tractor param type
# TR_P_P0 = 'pos.ra  '           / Tractor param name
# TR_P_P1 = 'pos.dec '           / Tractor param name
# TR_P_P2 = 'brightness.g'       / Tractor param name
# TR_P_P3 = 'brightness.r'       / Tractor param name
# TR_P_P4 = 'brightness.z'       / Tractor param name
# TR_P_T0 = 'tractor.pointsource.PointSource' / Tractor param type
# TR_P_T1 = 'tractor.wcs.RaDecPos' / Tractor param type
# TR_P_T2 = 'tractor.brightness.NanoMaggies' / Tractor param type
# TR_G_P0 = 'brightness.g'       / Tractor param name
# TR_G_P1 = 'brightness.r'       / Tractor param name
# TR_G_P2 = 'brightness.z'       / Tractor param name
# TR_G_T0 = 'legacypipe.survey.GaiaSource' / Tractor param type
# TR_G_T1 = 'legacypipe.survey.GaiaPosition' / Tractor param type
# TR_G_T2 = 'tractor.brightness.NanoMaggies' / Tractor param type

# %%
hdul.close()

# %%
from astropy.table import Table

# %%
data1_tab = Table.read(file)
data1_tab
# Out:
# <Table length=7142>
# release brickid brickname ... shapedev_e1_ivar shapedev_e2 shapedev_e2_ivar
#                           ...
#  int16   int32    bytes8  ...     float32        float32       float32
# ------- ------- --------- ... ---------------- ----------- ----------------
#    8000  328928  0001m002 ...              0.0         0.0              0.0
#    8000  328928  0001m002 ...              0.0         0.0              0.0
#    8000  328928  0001m002 ...              0.0         0.0              0.0
#    8000  328928  0001m002 ...              0.0         0.0              0.0
#    8000  328928  0001m002 ...              0.0         0.0              0.0
#    8000  328928  0001m002 ...              0.0         0.0              0.0
#    8000  328928  0001m002 ...              0.0         0.0              0.0
#    8000  328928  0001m002 ...              0.0         0.0              0.0
#    8000  328928  0001m002 ...              0.0         0.0              0.0
#     ...     ...       ... ...              ...         ...              ...
#    8000  328928  0001m002 ...              0.0         0.0              0.0
#    8000  328928  0001m002 ...              0.0         0.0              0.0
#    8000  328928  0001m002 ...              0.0         0.0              0.0
#    8000  328928  0001m002 ...              0.0         0.0              0.0
#    8000  328928  0001m002 ...              0.0         0.0              0.0
#    8000  328928  0001m002 ...              0.0         0.0              0.0
#    8000  328928  0001m002 ...              0.0         0.0              0.0
#    8000  328928  0001m002 ...              0.0         0.0              0.0
#    8000  328928  0001m002 ...              0.0         0.0              0.0
#    8000  328928  0001m002 ...              0.0         0.0              0.0

# %%
ra = data1_tab['ra']
dec = data1_tab['dec']

# %%
plt.scatter(ra, dec)
